# %%
import pandas as pd

# %%
t = pd.read_csv(r'C:\Users\lab408\YHY_work\lepu\文章_20260621\ProPepDesigner\data\result\base_validation_100.csv')
t.iloc[:100, :].to_csv(r'C:\Users\lab408\YHY_work\lepu\文章_20260621\ProPepDesigner\data\result\base_validation_100.csv', index=None)
